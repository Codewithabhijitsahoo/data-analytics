# %%
import pandas as pd

# %%
iris=pd.read_csv(r"D:\iris.data",header=None)
iris.columns=["sepal_length","sepal_width","petal_length","petal_width","class"]
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
iris['class']=le.fit_transform(iris['class'])

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class
# 0             5.1          3.5           1.4          0.2      0
# 1             4.9          3.0           1.4          0.2      0
# 2             4.7          3.2           1.3          0.2      0
# 3             4.6          3.1           1.5          0.2      0
# 4             5.0          3.6           1.4          0.2      0
# ..            ...          ...           ...          ...    ...
# 145           6.7          3.0           5.2          2.3      2
# 146           6.3          2.5           5.0          1.9      2
# 147           6.5          3.0           5.2          2.0      2
# 148           6.2          3.4           5.4          2.3      2
# 149           5.9          3.0           5.1          1.8      2
#
# [150 rows x 5 columns]

# %%
iris['class'].value_counts()
# Out:
# class
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
iris['class'].unique()
# Out:
# array([0, 1, 2])

# %%
le.inverse_transform([0,1,2])
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
corr=iris.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width     class
# sepal_length      1.000000    -0.109369      0.871754     0.817954  0.782561
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# petal_length      0.871754    -0.420516      1.000000     0.962757  0.949043
# petal_width       0.817954    -0.356544      0.962757     1.000000  0.956464
# class             0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# # ip / op creation

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
x=iris[['sepal_length','sepal_width','petal_length','petal_width']]
y=iris['class']

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: class, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 132           6.4          2.8           5.6          2.2
# 12            4.8          3.0           1.4          0.1
# 120           6.9          3.2           5.7          2.3
# 55            5.7          2.8           4.5          1.3
# 136           6.3          3.4           5.6          2.4
# ..            ...          ...           ...          ...
# 90            5.5          2.6           4.4          1.2
# 91            6.1          3.0           4.6          1.4
# 145           6.7          3.0           5.2          2.3
# 71            6.1          2.8           4.0          1.3
# 32            5.2          4.1           1.5          0.1
#
# [120 rows x 4 columns]

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 99            5.7          2.8           4.1          1.3
# 87            6.3          2.3           4.4          1.3
# 83            6.0          2.7           5.1          1.6
# 127           6.1          3.0           4.9          1.8
# 108           6.7          2.5           5.8          1.8
# 123           6.3          2.7           4.9          1.8
# 49            5.0          3.3           1.4          0.2
# 86            6.7          3.1           4.7          1.5
# 51            6.4          3.2           4.5          1.5
# 84            5.4          3.0           4.5          1.5
# 2             4.7          3.2           1.3          0.2
# 48            5.3          3.7           1.5          0.2
# 78            6.0          2.9           4.5          1.5
# 146           6.3          2.5           5.0          1.9
# 139           6.9          3.1           5.4          2.1
# 73            6.1          2.8           4.7          1.2
# 85            6.0          3.4           4.5          1.6
# 8             4.4          2.9           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 129           7.2          3.0           5.8          1.6
# 140           6.7          3.1           5.6          2.4
# 5             5.4          3.9           1.7          0.4
# 54            6.5          2.8           4.6          1.5
# 93            5.0          2.3           3.3          1.0
# 70            5.9          3.2           4.8          1.8
# 14            5.8          4.0           1.2          0.2
# 6             4.6          3.4           1.4          0.3
# 57            4.9          2.4           3.3          1.0
# 20            5.4          3.4           1.7          0.2
# 76            6.8          2.8           4.8          1.4

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[
#        [ 0.20554567,  0.92743629,  0.47570665,  0.6318696 ],
#        [-1.93927869, -0.27183477, -1.46467574, -1.44145252],
#        [-1.26902108, -0.03198056, -1.46467574, -1.44145252],
#        [ 1.81416394, -0.03198056,  1.2894154 ,  0.6318696 ],
#        [ 1.14390633,  0.20787365,  1.16422944,  1.81662509],
#        [-0.59876347,  2.12670735, -1.2768968 , -1.14526364],
#        [ 0.87580328, -0.51168899,  0.53829963,  0.48377516],
#        [-1.13496956, -1.71096005, -0.27540911, -0.25669702],
#        [ 0.07149415,  0.44772786,  0.66348559,  0.92805847],
#        [-0.06255738,  2.36656157, -1.58986171, -1.44145252],
#        [-1.67117565,  0.92743629, -1.46467574, -1.29335808],
#        [-1.26902108, -1.47110584, -0.27540911, -0.25669702],
#        [-0.59876347,  0.92743629, -1.2768968 , -1.44145252],
#        [ 1.27795785, -0.51168899,  0.66348559,  0.33568072]])

# %% [markdown]
# # applying logistic regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([1, 1, 2, 2, 2, 2, 0, 1, 1, 1, 0, 0, 1, 2, 2, 1, 1, 0, 0, 2, 2, 0,
#        1, 1, 2, 0, 0, 1, 0, 1])

# %%
y_test
# Out:
# 99     1
# 87     1
# 83     1
# 127    2
# 108    2
# 123    2
# 49     0
# 86     1
# 51     1
# 84     1
# 2      0
# 48     0
# 78     1
# 146    2
# 139    2
# 73     1
# 85     1
# 8      0
# 1      0
# 129    2
# 140    2
# 5      0
# 54     1
# 93     1
# 70     1
# 14     0
# 6      0
# 57     1
# 20     0
# 76     1
# Name: class, dtype: int32

# %%
df=pd.DataFrame({'y_test(original_answer)':list(y_test),
                 'y_pred(machine_generate answer)':list(y_pred)
                })
df
# Out:
#     y_test(original_answer)  y_pred(machine_generate answer)
# 0                         1                                1
# 1                         1                                1
# 2                         1                                2
# 3                         2                                2
# 4                         2                                2
# 5                         2                                2
# 6                         0                                0
# 7                         1                                1
# 8                         1                                1
# 9                         1                                1
# 10                        0                                0
# 11                        0                                0
# 12                        1                                1
# 13                        2                                2
# 14                        2                                2
# 15                        1                                1
# 16                        1                                1
# 17                        0                                0
# 18                        0                                0
# 19                        2                                2
# 20                        2                                2
# 21                        0                                0
# 22                        1                                1
# 23                        1                                1
# 24                        1                                2
# 25                        0                                0
# 26                        0                                0
# 27                        1                                1
# 28                        0                                0
# 29                        1                                1

# %% [markdown]
# # confusion matrix

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
acc=accuracy_score(y_pred,y_test)
pre=precision_score(y_pred,y_test,average='weighted')
rec=recall_score(y_pred,y_test,average='weighted')
f1=f1_score(y_pred,y_test,average='weighted')

# %%
print("ACCURACY",acc)
print('PRECISION',pre)
print('recall',rec)
print('f1_score',f1)
# Out:
# ACCURACY 0.9333333333333333
# PRECISION 0.9428571428571428
# recall 0.9333333333333333
# f1_score 0.9317307692307693

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

# %%
cm=confusion_matrix(y_pred,y_test)
cm
# Out:
# array([[ 9,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  2,  7]], dtype=int64)

# %%
cmd=ConfusionMatrixDisplay(cm)
cmd.plot()
