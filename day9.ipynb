# %% [markdown]
# # seaborn

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv(r"D:\iris.data",header=None)
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.columns=['sl','sw','pl','pw','flower']

# %%
iris.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower'], dtype='object')

# %%
iris.head()
# Out:
#     sl   sw   pl   pw       flower
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
#scatter plot
sns.scatterplot(x=iris.sw,y=iris.sl)
plt.show()

# %%
sns.scatterplot(x=iris.pl,y=iris.pw)
plt.show()

# %%
#dist plot(dis plot + kde plot ): use to display the distribution of data points
sns.distplot(iris.sl)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9744\972229240.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris.sl)

# %%
#dis plot(): use to display teh distribution of  a single variable using histogram
sns.displot(iris.sl)
plt.show()

# %%
#box plot(): use to see statistical information 
sns.boxplot(x=iris.flower,y=iris.sw,hue=iris.flower)
plt.show()

# %%
sns.boxplot(x=iris.flower,y=iris.sw,palette='cool')
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9744\3809382016.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=iris.flower,y=iris.sw,palette='cool')

# %%
#boxen plot

sns.boxenplot(x=iris.flower,y=iris.sw,hue=iris.flower)
plt.show()

# %%
# bar plot: use display yhe mean of a variable along with the categorical data
sns.barplot(x=iris.flower,y=iris.sw,hue=iris.flower)
plt.show()

# %%
#count plot(): show the count of each categories
sns.countplot(x=iris.flower,hue=iris.flower)
plt.show()

# %%
#pair plot: show relationship  between contineous column with contineous column
sns.pairplot(data=iris)
plt.show()

# %%
sns.pairplot(data=iris,hue='flower')
plt.show()

# %%
# titanic datasets

# %%
import pandas as pd
import seaborn as sns
titanic=pd.read_csv(r"D:\titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.scatterplot(x='PassengerId',y='Age',data=titanic)

plt.show()

# %%
sns.countplot(x=titanic.Survived)
plt.show()

# %%
sns.countplot(x=titanic.Pclass)
plt.show()

# %%
sns.countplot(x=titanic.Sex)
plt.show()

# %%
sns.distplot(titanic.Survived)
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9744\1741033120.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic.Survived)

# %%
sns.pairplot(data=titanic,hue="Sex")
plt.show()

# %%
sns.pointplot(x=titanic.Survived,y=titanic.PassengerId)
plt.show()

# %%
# heat-map: shows tge corelation of the data

cor=iris.corr()
cor
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 3
#       1 # heat-map: shows tge corelation of the data
# ----> 3 cor=iris.corr()
#       4 cor
#
# File D:\new\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File D:\new\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
iris=iris.drop('flower',axis=1)
iris
# Out:
#       sl   sw   pl   pw
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
cor=iris.corr()
cor
# Out:
#           sl        sw        pl        pw
# sl  1.000000 -0.109369  0.871754  0.817954
# sw -0.109369  1.000000 -0.420516 -0.356544
# pl  0.871754 -0.420516  1.000000  0.962757
# pw  0.817954 -0.356544  0.962757  1.000000

# %%
sns.heatmap(cor,annot=True)
plt.show()
